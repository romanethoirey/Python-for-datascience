# %% [markdown]
# # A small linear regression with scikit learn

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import math

from sklearn.linear_model import LinearRegression
from sklearn import metrics

# %% [markdown]
# Load the dataset house.csv with pandas into the variable **df**

# %%
df = pd.read_csv("./house.csv")

# %% [markdown]
# Check on the internet how to plot the correlations between variables and plot them

# %%
# pd.scatter_matrix(df, figsize=(6, 6))
sns.pairplot(df)
plt.show()

# %% [markdown]
# In the linear model module of scikit learn import the LinearRegression module and instanciate a LinearRegression object in the **model** variable

# %%
model = LinearRegression()

# %% [markdown]
# Select the column containing the number the size of the house and put it into a variable **X** (use double bracket to select the column).
# Select the column price and put it in the variable **y**

# %%
X = df[['size']]
y = df[['price']]

# %% [markdown]
# Use the fit method on X and y of the **model** variable. It will automatically find the best parameters of the linear regression

# %%
model.fit(X, y)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#          normalize=False)

# %% [markdown]
# Create a numpy array with values from 0 to 300 evenly spaced with the numpy function arange

# %%
sizes = np.arange(300).reshape(300,1)

# %% [markdown]
# Compute the price associated to each of the values of the previous array.

# %%
prediction_price = model.predict(sizes)

# %% [markdown]
# Plot both the scatter plot of the houses (price versus size) and the predicted prices versus the sizes

# %%
plt.scatter(sizes, prediction_price, c='red', marker='+')
plt.plot(X,y)
plt.show()

# %% [markdown]
# Display the coefficients of the linear regression (look at the linear_regression attributes ) in the doc

# %%
model.coef_, model.intercept_
# Out:
# (array([[10001.00319699]]), array([654.99477315]))

# %% [markdown]
# Display the MSE. Display the R<sup>2</sup> coefficient (what is it) ?

# %%
y_test = model.predict(X)
mse = metrics.mean_squared_error(y, y_test)
math.sqrt(mse)
# Out:
# 2475.519190271693

# %%
metrics.r2_score(y,y_test)
# Out:
# 0.9999747882044046
