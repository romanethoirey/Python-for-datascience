# %% [markdown]
# # Pandas

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## Time series data
#
# Pandas was originaly developed for time series data and is very good for them.

# %% [markdown]
# Generate a dataframe containing a datetime column starting from January the first 2019 until March the first 2019 with each row representing an hour. The Datetime should be the index of the dataframe. In the following you may be interested in the special attribute .dt of timeseries dataframe. What does it do ? What does it contain ?
#
# Generate a second column containing random values for each row of the time serie

# %%
hours = pd.date_range('01-01-2019', '03-01-2019', freq='H')
datetime = pd.DataFrame({'Val': np.random.randn(len(hours))})
datetime = datetime.set_index(hours, drop=True, append=False, inplace=False, verify_integrity=False)
datetime
# Out:
#                           Val
# 2019-01-01 00:00:00 -1.154068
# 2019-01-01 01:00:00  0.098155
# 2019-01-01 02:00:00 -0.855781
# 2019-01-01 03:00:00  0.479203
# 2019-01-01 04:00:00 -0.124756
# 2019-01-01 05:00:00 -0.720241
# 2019-01-01 06:00:00  0.254456
# 2019-01-01 07:00:00  1.579469
# 2019-01-01 08:00:00  0.539652
# 2019-01-01 09:00:00 -0.287226
# 2019-01-01 10:00:00 -0.165817
# 2019-01-01 11:00:00 -0.921008
# 2019-01-01 12:00:00 -1.417836
# 2019-01-01 13:00:00 -0.601053
# 2019-01-01 14:00:00 -0.124936
# 2019-01-01 15:00:00 -1.175218
# 2019-01-01 16:00:00 -0.035203
# 2019-01-01 17:00:00 -2.107401
# 2019-01-01 18:00:00 -0.555759
# 2019-01-01 19:00:00 -0.267069
# 2019-01-01 20:00:00 -2.624324
# 2019-01-01 21:00:00  1.669733
# 2019-01-01 22:00:00  0.073449
# 2019-01-01 23:00:00 -0.736560
# 2019-01-02 00:00:00 -0.838242
# 2019-01-02 01:00:00  0.848245
# 2019-01-02 02:00:00 -1.275789
# 2019-01-02 03:00:00  1.122741
# 2019-01-02 04:00:00  0.563651
# 2019-01-02 05:00:00 -1.472329
# ...

# %% [markdown]
# Compute the mean for each day of the month

# %%
datetime.groupby(datetime.index.day).mean() # methode resample pour les jours du mois c'est bien avec les times séries
# Out:
#          Val
# 1  -0.237941
# 2   0.069161
# 3   0.033993
# 4  -0.095012
# 5  -0.131497
# 6  -0.136484
# 7  -0.204802
# 8  -0.149011
# 9   0.055919
# 10  0.084538
# 11 -0.139111
# 12  0.056420
# 13  0.301101
# 14 -0.074043
# 15 -0.049201
# 16  0.122242
# 17 -0.090640
# 18  0.166606
# 19 -0.293004
# 20  0.002840
# 21  0.074674
# 22 -0.193795
# 23 -0.196097
# 24 -0.168784
# 25  0.195425
# 26  0.087500
# 27  0.133866
# 28 -0.212263
# 29 -0.200068
# 30 -0.066491
# 31 -0.315508

# %% [markdown]
# Compute the median for each day of the week

# %%
datetime.groupby(datetime.index.week).median()
# Out:
#         Val
# 1 -0.083284
# 2 -0.020696
# 3 -0.017284
# 4 -0.045823
# 5 -0.220233
# 6 -0.009761
# 7  0.012867
# 8 -0.041473
# 9  0.058646

# %% [markdown]
# Select all values from february

# %%
datetime[datetime.index.month == 2]
# Out:
#                           Val
# 2019-02-01 00:00:00  0.387523
# 2019-02-01 01:00:00 -0.264984
# 2019-02-01 02:00:00 -0.043319
# 2019-02-01 03:00:00  0.522449
# 2019-02-01 04:00:00 -0.550226
# 2019-02-01 05:00:00 -1.510651
# 2019-02-01 06:00:00 -1.612089
# 2019-02-01 07:00:00  1.966897
# 2019-02-01 08:00:00 -0.756240
# 2019-02-01 09:00:00  0.339739
# 2019-02-01 10:00:00 -0.579100
# 2019-02-01 11:00:00  0.727029
# 2019-02-01 12:00:00 -1.343097
# 2019-02-01 13:00:00 -0.795502
# 2019-02-01 14:00:00  0.282566
# 2019-02-01 15:00:00  0.867405
# 2019-02-01 16:00:00 -0.083279
# 2019-02-01 17:00:00 -0.442657
# 2019-02-01 18:00:00 -0.192025
# 2019-02-01 19:00:00  1.295558
# 2019-02-01 20:00:00 -1.169677
# 2019-02-01 21:00:00 -0.263127
# 2019-02-01 22:00:00  0.537251
# 2019-02-01 23:00:00 -0.379933
# 2019-02-02 00:00:00 -0.432004
# 2019-02-02 01:00:00 -0.516110
# 2019-02-02 02:00:00  2.680839
# 2019-02-02 03:00:00 -0.319456
# 2019-02-02 04:00:00  1.613588
# 2019-02-02 05:00:00 -0.724898
# ...

# %% [markdown]
# Compute the moving average of the random values with a window of three hours. Série of means on a small portion of the data.

# %%
datetime.rolling(window=3).mean()
# Out:
#                           Val
# 2019-01-01 00:00:00       NaN
# 2019-01-01 01:00:00       NaN
# 2019-01-01 02:00:00 -0.637231
# 2019-01-01 03:00:00 -0.092808
# 2019-01-01 04:00:00 -0.167111
# 2019-01-01 05:00:00 -0.121931
# 2019-01-01 06:00:00 -0.196847
# 2019-01-01 07:00:00  0.371228
# 2019-01-01 08:00:00  0.791192
# 2019-01-01 09:00:00  0.610632
# 2019-01-01 10:00:00  0.028870
# 2019-01-01 11:00:00 -0.458017
# 2019-01-01 12:00:00 -0.834887
# 2019-01-01 13:00:00 -0.979966
# 2019-01-01 14:00:00 -0.714608
# 2019-01-01 15:00:00 -0.633736
# 2019-01-01 16:00:00 -0.445119
# 2019-01-01 17:00:00 -1.105941
# 2019-01-01 18:00:00 -0.899454
# 2019-01-01 19:00:00 -0.976743
# 2019-01-01 20:00:00 -1.149051
# 2019-01-01 21:00:00 -0.407220
# 2019-01-01 22:00:00 -0.293714
# 2019-01-01 23:00:00  0.335541
# 2019-01-02 00:00:00 -0.500451
# 2019-01-02 01:00:00 -0.242185
# 2019-01-02 02:00:00 -0.421929
# 2019-01-02 03:00:00  0.231732
# 2019-01-02 04:00:00  0.136867
# 2019-01-02 05:00:00  0.071354
# ...

# %% [markdown]
# ## Weather data
#
# Load the following data set which contains time series data of the weather in Toronto. When you do read_csv you can specify to parse date for several columns. You can also decide to make a given column as an index. Parse the date and put as the index

# %%
weather = pd.read_csv('data_weather_montreal.csv', index_col ='Date/Time', parse_dates=True)
weather
# Out:
#                      Longitude (x)  Latitude (y)        Station Name  \
# Date/Time
# 2019-10-01 00:00:00         -73.42         45.52  MONTREAL/ST-HUBERT
# 2019-10-01 01:00:00         -73.42         45.52  MONTREAL/ST-HUBERT
# 2019-10-01 02:00:00         -73.42         45.52  MONTREAL/ST-HUBERT
# 2019-10-01 03:00:00         -73.42         45.52  MONTREAL/ST-HUBERT
# 2019-10-01 04:00:00         -73.42         45.52  MONTREAL/ST-HUBERT
# 2019-10-01 05:00:00         -73.42         45.52  MONTREAL/ST-HUBERT
# 2019-10-01 06:00:00         -73.42         45.52  MONTREAL/ST-HUBERT
# 2019-10-01 07:00:00         -73.42         45.52  MONTREAL/ST-HUBERT
# 2019-10-01 08:00:00         -73.42         45.52  MONTREAL/ST-HUBERT
# 2019-10-01 09:00:00         -73.42         45.52  MONTREAL/ST-HUBERT
# 2019-10-01 10:00:00         -73.42         45.52  MONTREAL/ST-HUBERT
# 2019-10-01 11:00:00         -73.42         45.52  MONTREAL/ST-HUBERT
# ...

# %% [markdown]
# Display the columns

# %%
weather.columns
# Out:
# Index(['Longitude (x)', 'Latitude (y)', 'Station Name', 'Climate ID', 'Year',
#        'Month', 'Day', 'Time', 'Temp (°C)', 'Temp Flag', 'Dew Point Temp (°C)',
#        'Dew Point Temp Flag', 'Rel Hum (%)', 'Rel Hum Flag',
#        'Wind Dir (10s deg)', 'Wind Dir Flag', 'Wind Spd (km/h)',
#        'Wind Spd Flag', 'Visibility (km)', 'Visibility Flag',
#        'Stn Press (kPa)', 'Stn Press Flag', 'Hmdx', 'Hmdx Flag', 'Wind Chill',
#        'Wind Chill Flag', 'Weather'],
#       dtype='object')

# %% [markdown]
# Rename the column Temp (° C) into temperature

# %%
weather.rename({'Temp (°C)': 'temperature'}, inplace=True, axis='columns')

# %% [markdown]
# Plot the Temperature versus the time

# %%
import matplotlib.pyplot as plt

plt.plot(weather.index, weather['temperature'])

# %% [markdown]
# Compute the mean and median temperature for each hour of the day and plot it

# %%
daily_temp = weather['temperature'].resample('d', how='mean')
plt.plot(daily_temp)
# Out:
# /Users/romane/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: FutureWarning: how in .resample() is deprecated
# the new syntax is .resample(...).mean()
#   """Entry point for launching an IPython kernel.

# %%
daily_temp
# Out:
# Date/Time
# 2019-10-01    12.666667
# 2019-10-02    10.070833
# 2019-10-03     5.487500
# 2019-10-04     6.612500
# 2019-10-05     5.845833
# 2019-10-06    10.879167
# 2019-10-07    13.250000
# 2019-10-08    11.612500
# 2019-10-09     8.587500
# 2019-10-10    10.591667
# 2019-10-11    11.004167
# 2019-10-12    12.170833
# 2019-10-13    10.133333
# 2019-10-14     9.895833
# 2019-10-15     8.204167
# 2019-10-16    10.825000
# 2019-10-17     7.375000
# 2019-10-18     8.029167
# 2019-10-19     5.695833
# 2019-10-20     4.979167
# 2019-10-21     7.337500
# 2019-10-22    11.275000
# 2019-10-23    12.083333
# 2019-10-24          NaN
# 2019-10-25          NaN
# 2019-10-26          NaN
# 2019-10-27          NaN
# 2019-10-28          NaN
# 2019-10-29          NaN
# 2019-10-30          NaN
# 2019-10-31          NaN
# Freq: D, Name: temperature, dtype: float64
